# %% [markdown]
# # Load needed libraries

# %%
import numpy as np
import networkx as nx

# %% [markdown]
# # Initializing nx-class graphs

# %%
G = nx.Graph()
nodes = ['a', 'b', 'c', 'd', 'e']
G.add_nodes_from(nodes)
edges = [('a', 'b'), ('a', 'c'), ('a', 'd'), ('a', 'e'),
         ('b', 'c'), ('b', 'e'),
         ('c', 'd'),
         ('d', 'e')]
